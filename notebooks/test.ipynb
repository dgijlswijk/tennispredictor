# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\davev\OneDrive\Projects\tennispredictor\data\processed\features.csv')

# %%
df
# Out:
#      result  id_home  id_away   age_home   age_away  round_ordinal  \
# 0      away    15229    15963  17.620808  38.431211              4
# 1      home    15963    15229  38.431211  17.620808              4
# 2      away    14527    14341   4.613279  38.447639              4
# 3      home    15300    14420   8.224504  27.162218              4
# 4      home    14341    14527  38.447639   4.613279              4
# ...     ...      ...      ...        ...        ...            ...
# 5235   away    57163    14882  22.819986  30.458590              9
# 5236   away    14882   206570  30.464066  43.756331             10
# 5237   home   206570    14882  43.756331  30.464066             10
# 5238   home   275923   206570  38.294319  43.761807             11
# 5239   away   206570   275923  43.761807  38.294319             11
#
#          month_sin  month_cos  month_5  month_6  month_9  month_10  \
# 0     5.000000e-01  -0.866025     True    False    False     False
# ...

# %%
corr_with_y = df.corrwith(df['result'].map({'away': 0, 'home': 1}))
print(corr_with_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 corr_with_y = df.corrwith(df['result'].map({'away': 0, 'home': 1}))
#       2 print(corr_with_y)
#
# File c:\Users\davev\OneDrive\Projects\tennispredictor\.venv\Lib\site-packages\pandas\core\frame.py:11302, in DataFrame.corrwith(self, other, axis, drop, method, numeric_only)
#   11299 this = self._get_numeric_data() if numeric_only else self
#   11301 if isinstance(other, Series):
# > 11302     return this.apply(lambda x: other.corr(x, method=method), axis=axis)
#   11304 if numeric_only:
#   11305     other = other._get_numeric_data()
#
# File c:\Users\davev\OneDrive\Projects\tennispredictor\.venv\Lib\site-packages\pandas\core\frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
# ...

# %%
df = pd.read_csv(r'C:\Users\davev\OneDrive\Projects\tennispredictor\data\processed\games.csv')

# %%
df
# Out:
#       finished result  homeTeamScore  awayTeamScore       id      events  \
# 0         True    3:0              3              0   390606   [6749490]
# 1         True    3:2              3              2   390596   [6749491]
# 2         True    1:3              1              3   390624   [6749935]
# 3         True    1:3              1              3   390608   [6749933]
# 4         True    3:0              3              0   390571   [6749937]
# ...        ...    ...            ...            ...      ...         ...
# 2615      True    2:0              2              0  2764928  [13929123]
# 2616      True    2:1              2              1  2764935  [13930473]
# 2617      True    0:2              0              2  2764942  [13929464]
# 2618      True    2:0              2              0  2764949  [13929741]
# 2619      True    1:2              1              2  2764956  [13924775]
#
#           seriesStartDate  home_id  away_id round_description  \
# ...
